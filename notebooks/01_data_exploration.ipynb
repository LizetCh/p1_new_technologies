# %% [markdown]
# # 01 Data Exploration
#
# This notebook is used to explore the raw CSV files before loading them into PostgreSQL.
#
# For each dataset, the structure should be:
#
# ```text
# 1. Read the raw CSV file
# 2. Preview sample records
# 3. Identify possible cleaning or transformation rules
# ```

# %% [markdown]
# ## 1. Import libraries and define paths
#
# This section imports the required Python libraries and defines the folder paths used to read the raw CSV files.

# %%
import pandas as pd

# %% [markdown]
# ## 2. customers_medium data exploration

# %%
customers = pd.read_csv("../data/raw/customers/customers01.csv")
customers.head()
# Out:
#   customer_id        city signup_date
# 0       C0001     Bristol  2022-04-25
# 1       C0002      London  2022-10-09
# 2       C0003  Manchester  2022-08-17
# 3       C0004  Manchester  2022-04-15
# 4       C0005     Bristol  2023-07-13

# %%
customers.info()
customers.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1500 non-null   str
#  1   city         1500 non-null   str
#  2   signup_date  1500 non-null   str
# dtypes: str(3)
# memory usage: 68.7 KB
# customer_id    0
# city           0
# signup_date    0
# dtype: int64

# %%
customers["customer_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["city"].unique()
# Out:
# <ArrowStringArray>
# ['Bristol', 'London', 'Manchester', 'Leeds', 'Liverpool', 'Birmingham']
# Length: 6, dtype: str

# %%
customers["signup_date"].min(), customers["signup_date"].max()
# Out:
# ('2022-01-01', '2023-12-01')
