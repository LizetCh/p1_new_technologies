# %%
import pandas as pd

# %%
df = pd.read_csv('../data/order_items.csv')

# %%
df.head()
# Out:
#   order_id item_id  quantity  price
# 0   O00001   M0197         2   7.93
# 1   O00001   M0223         1  14.20
# 2   O00001   M0196         3  26.56
# 3   O00001   M0326         3   6.03
# 4   O00002   M0172         3  35.65
